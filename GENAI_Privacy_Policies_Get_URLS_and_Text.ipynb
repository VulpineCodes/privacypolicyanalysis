# %% [markdown]
# <a href="https://colab.research.google.com/github/VulpineCodes/privacypolicyanalysis/blob/main/GENAI_Privacy_Policies_Get_URLS_and_Text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
 # !pip install scrapy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 44.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.8/247.8 kB 31.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.6/97.6 kB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 11.0 MB/s eta 0:00:00
# ...

# %%
 # !pip install waybackpy

# %%
#Import pandas and beautiful soup first in the empty lines below

#other imports
import sys
import requests as rq
from time import sleep
from time import time
from random import randint
from warnings import warn
import json
from datetime import datetime as dt
import scrapy
from waybackpy import WaybackMachineSaveAPI
from waybackpy import WaybackMachineCDXServerAPI
import pandas as pd
from bs4 import BeautifulSoup

# %%
#We will want to open our dataset which is just the csv of your privacy policy urls via pandas
# df = pd.read_csv("/content/drive/MyDrive/SOCKS research/GENAI_Privacy_Policy_URLS - Sheet1.csv")
df = pd.read_csv("/content/drive/MyDrive/RESEARCH/PROJECTS/2024_Gen_AI_Privacy_Policies/GENAI_Privacy_Policy_URLS.csv")

# %%
df
# Out:
#          Company                                 URL_Privacy_Policy
# 0         OpenAI        https://openai.com/policies/privacy-policy/
# 1       Antropic            https://www.anthropic.com/legal/privacy
# 2  Google Gemini  https://support.google.com/gemini/answer/13594...
# 3  Perplexity AI  https://www.perplexity.ai/hub/legal/privacy-po...

# %% [markdown]
# #test the scraper

# %%
#testing it out on one first before committing to scraping everything

# Define the URL to be tested
url = "https://openai.com/policies/privacy-policy/"

# Define the User Agent string
user_agent = "Mozilla/5.0 (Windows NT 5.1; rv:40.0) Gecko/20100101 Firefox/40.0"

# Initialize the WaybackMachineCDXServerAPI with the URL, user agent, and time range
cdx_api = WaybackMachineCDXServerAPI(url, user_agent, start_timestamp=2022, end_timestamp=2024)

# Initialize lists to store the URLs and timestamps of the snapshots
urls = []
timestamps = []

# Iterate over each snapshot retrieved from the Wayback Machine
for item in cdx_api.snapshots():
  # Extract the date part (YYYYMMDD) of the timestamp and append it to the timestamps list
  timestamps.append(item.timestamp[0:8])

  # Append the archive URL to the urls list
  urls.append(item.archive_url)

new_df = pd.DataFrame({
    'URL': urls,
    'Timestamp': timestamps,
    'Company_name': 'OpenAI'
  })

new_df
# Out:
#                                                     URL Timestamp Company_name
# 0     https://web.archive.org/web/20230227230602/htt...  20230227       OpenAI
# 1     https://web.archive.org/web/20230227235853/htt...  20230227       OpenAI
# 2     https://web.archive.org/web/20230228064826/htt...  20230228       OpenAI
# 3     https://web.archive.org/web/20230228124107/htt...  20230228       OpenAI
# 4     https://web.archive.org/web/20230301171100/htt...  20230301       OpenAI
# ...                                                 ...       ...          ...
# 2261  https://web.archive.org/web/20240706231744/htt...  20240706       OpenAI
# 2262  https://web.archive.org/web/20240706231745/htt...  20240706       OpenAI
# 2263  https://web.archive.org/web/20240708052959/htt...  20240708       OpenAI
# 2264  https://web.archive.org/web/20240708232624/htt...  20240708       OpenAI
# 2265  https://web.archive.org/web/20240708232624/htt...  20240708       OpenAI
#
# [2266 rows x 3 columns]

# %%
openaidf = new_df
openaidf
# Out:
#                                                     URL Timestamp Company_name
# 0     https://web.archive.org/web/20230227230602/htt...  20230227       OpenAI
# 1     https://web.archive.org/web/20230227235853/htt...  20230227       OpenAI
# 2     https://web.archive.org/web/20230228064826/htt...  20230228       OpenAI
# 3     https://web.archive.org/web/20230228124107/htt...  20230228       OpenAI
# 4     https://web.archive.org/web/20230301171100/htt...  20230301       OpenAI
# ...                                                 ...       ...          ...
# 2261  https://web.archive.org/web/20240706231744/htt...  20240706       OpenAI
# 2262  https://web.archive.org/web/20240706231745/htt...  20240706       OpenAI
# 2263  https://web.archive.org/web/20240708052959/htt...  20240708       OpenAI
# 2264  https://web.archive.org/web/20240708232624/htt...  20240708       OpenAI
# 2265  https://web.archive.org/web/20240708232624/htt...  20240708       OpenAI
#
# [2266 rows x 3 columns]

# %%
#testing it out on one first before committing to scraping everything

# Define the URL to be tested
url = "https://www.anthropic.com/legal/privacy"

# Define the User Agent string
user_agent = "Mozilla/5.0 (Windows NT 5.1; rv:40.0) Gecko/20100101 Firefox/40.0"

# Initialize the WaybackMachineCDXServerAPI with the URL, user agent, and time range
cdx_api = WaybackMachineCDXServerAPI(url, user_agent, start_timestamp=2022, end_timestamp=2024)

# Initialize lists to store the URLs and timestamps of the snapshots
urls = []
timestamps = []

# Iterate over each snapshot retrieved from the Wayback Machine
for item in cdx_api.snapshots():
  # Extract the date part (YYYYMMDD) of the timestamp and append it to the timestamps list
  timestamps.append(item.timestamp[0:8])

  # Append the archive URL to the urls list
  urls.append(item.archive_url)

antropic_df = pd.DataFrame({
    'URL': urls,
    'Timestamp': timestamps,
    'Company_name': 'Antropic'
  })

antropic_df
# Out:
#                                                   URL Timestamp Company_name
# 0   https://web.archive.org/web/20240225205441/htt...  20240225     Antropic
# 1   https://web.archive.org/web/20240226052059/htt...  20240226     Antropic
# 2   https://web.archive.org/web/20240303100123/htt...  20240303     Antropic
# 3   https://web.archive.org/web/20240304151321/htt...  20240304     Antropic
# 4   https://web.archive.org/web/20240304180518/htt...  20240304     Antropic
# 5   https://web.archive.org/web/20240306072423/htt...  20240306     Antropic
# 6   https://web.archive.org/web/20240308101039/htt...  20240308     Antropic
# 7   https://web.archive.org/web/20240312070444/htt...  20240312     Antropic
# 8   https://web.archive.org/web/20240320125823/htt...  20240320     Antropic
# 9   https://web.archive.org/web/20240327175244/htt...  20240327     Antropic
# 10  https://web.archive.org/web/20240327181839/htt...  20240327     Antropic
# ...

# %%
#save each dataframe to a csv file to our shared drive

# %% [markdown]
# #WaybackMachine Scraper Get URLS

# %%
# #create a function that gets the the urls and timestamps for every row in data frame and saves it to a new dataframe

# def scraper_get_url_timestamp(company_name, company_url, start_year, end_year):
#   USER_AGENT = "Mozilla/5.0 (Windows NT 5.1; rv:40.0) Gecko/20100101 Firefox/40.0"

#   cdx_api = WaybackMachineCDXServerAPI(company_url, user_agent, start_timestamp=start_year, end_timestamp=end_year)
#   print(cdx_api)

#   # Initialize lists to store the URLs and timestamps of the snapshots
#   url_list = []
#   timestamp_list = []
#   company_name = []

#   # Iterate over each snapshot retrieved from the Wayback Machine

#   for item in cdx_api.snapshots():
#     url_list.append(item.archive_url)
#     # print(item)
#     timestamp_list.append(item.timestamp[0:8])
#     # print(item)
#     company_name.append(company_name)
#     # print(item)

#   # Create a DataFrame with URLs and their timestamps
#   new_df = pd.DataFrame({
#     'URL': url_list,
#     'Timestamp': timestamp_list,
#     'Company_name': company_name
#   })

#   # Return the new DataFrame
#   return new_df

# OpenAI_df = scraper_get_url_timestamp(df['Company'].iloc[0], df['URL_Privacy_Policy'].iloc[0], 2022, 2024)

# %% [markdown]
# #WaybackMachine Scraper Get Text

# %%
#making a copy of your dataframe so you have a checkpoint

# %%
#to do scrape text from just one URL and make sure that it works

# %%
#create a function that gets the the urls text for every row in data frame and saves it to a new dataframe
#scrape the text and with a 3 second delay

def text_delay(df, varX, varZ):
  for i, row in df.iterrows():
    try:
      page = requests.get(df.loc[i, varX])
      soup = BeautifulSoup(page.content, 'html.parser')
      df.loc[i, varZ] = soup.prettify()
      time.sleep(3)
    except:
      continue
  return df

# %%
#apply the function aboce to the urls and put them in a their respectice column

# %% [markdown]
# #check point 2 save your work

# %%
#Save data frame to a csv file
